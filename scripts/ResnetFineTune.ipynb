# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the DAiSEE.zip file in Google Drive
# Users can change this path if their file is located elsewhere in their Drive
DAISEE_ZIP_PATH = '/content/drive/MyDrive/DAiSEE.zip'

# Unzip the file to the content directory
# !unzip {DAISEE_ZIP_PATH} -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601052/2100601052.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601052/._2100601052.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601064/2100601064.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601064/._2100601064.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602043/2100602043.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602043/._2100602043.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602044/2100602044.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602044/._2100602044.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601063/2100601063.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601063/._2100601063.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602027/2100602027.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602027/._2100602027.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602018/2100602018.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602018/._2100602018.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602020/2100602020.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602020/._2100602020.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601007/2100601007.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601007/._2100601007.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601038/2100601038.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601038/._2100601038.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601031/2100601031.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601031/._2100601031.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602029/2100602029.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602029/._2100602029.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601036/2100601036.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601036/._2100601036.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602011/2100602011.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602011/._2100602011.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601009/2100601009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601009/._2100601009.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601062/2100601062.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601062/._2100601062.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100602042/2100602042.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100602042/._2100602042.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601065/2100601065.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601065/._2100601065.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601053/2100601053.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601053/._2100601053.avi
#   inflating: /content/DAiSEE/DataSet/Train/210060/2100601054/2100601054.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/210060/2100601054/._2100601054.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131006/1100131006.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131006/._1100131006.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131009/1100131009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131009/._1100131009.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131007/1100131007.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131007/._1100131007.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131012/1100131012.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131012/._1100131012.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131019/1100131019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131019/._1100131019.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131017/1100131017.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131017/._1100131017.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131010/1100131010.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131010/._1100131010.avi
#   inflating: /content/DAiSEE/DataSet/Train/110013/1100131011/1100131011.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110013/1100131011/._1100131011.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501030/2000501030.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501030/._2000501030.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502010/2000502010.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502010/._2000502010.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501037/2000501037.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501037/._2000501037.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501001/2000501001.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501001/._2000501001.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502019/2000502019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502019/._2000502019.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501006/2000501006.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501006/._2000501006.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501039/2000501039.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501039/._2000501039.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502081/2000502081.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502081/._2000502081.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501052/2000501052.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501052/._2000501052.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502075/2000502075.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502075/._2000502075.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502072/2000502072.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502072/._2000502072.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502044/2000502044.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502044/._2000502044.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501063/2000501063.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501063/._2000501063.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502088/2000502088.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502088/._2000502088.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502043/2000502043.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502043/._2000502043.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502020/2000502020.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502020/._2000502020.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501038/2000501038.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501038/._2000501038.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501036/2000501036.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501036/._2000501036.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501009/2000501009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501009/._2000501009.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501031/2000501031.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501031/._2000501031.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501065/2000501065.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501065/._2000501065.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501062/2000501062.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501062/._2000501062.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502045/2000502045.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502045/._2000502045.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501054/2000501054.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501054/._2000501054.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502087/2000502087.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502087/._2000502087.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502073/2000502073.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502073/._2000502073.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501053/2000501053.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501053/._2000501053.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502056/2000502056.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502056/._2000502056.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501071/2000501071.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501071/._2000501071.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502069/2000502069.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502069/._2000502069.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501076/2000501076.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501076/._2000501076.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502051/2000502051.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502051/._2000502051.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501049/2000501049.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501049/._2000501049.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501040/2000501040.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501040/._2000501040.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502067/2000502067.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502067/._2000502067.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502058/2000502058.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502058/._2000502058.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501078/2000501078.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501078/._2000501078.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501014/2000501014.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501014/._2000501014.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502033/2000502033.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502033/._2000502033.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502005/2000502005.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502005/._2000502005.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502002/2000502002.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502002/._2000502002.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501046/2000501046.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501046/._2000501046.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502061/2000502061.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502061/._2000502061.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502066/2000502066.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502066/._2000502066.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501041/2000501041.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501041/._2000501041.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502059/2000502059.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502059/._2000502059.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502050/2000502050.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502050/._2000502050.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502057/2000502057.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502057/._2000502057.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501023/2000501023.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501023/._2000501023.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501015/2000501015.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501015/._2000501015.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501012/2000501012.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501012/._2000501012.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501056/2000501056.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501056/._2000501056.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502049/2000502049.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502049/._2000502049.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501051/2000501051.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501051/._2000501051.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502076/2000502076.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502076/._2000502076.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501067/2000501067.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501067/._2000501067.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502040/2000502040.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502040/._2000502040.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502078/2000502078.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502078/._2000502078.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502047/2000502047.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502047/._2000502047.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501060/2000501060.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501060/._2000501060.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502013/2000502013.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502013/._2000502013.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501033/2000501033.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501033/._2000501033.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502014/2000502014.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502014/._2000502014.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502025/2000502025.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502025/._2000502025.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501002/2000501002.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501002/._2000501002.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501061/2000501061.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501061/._2000501061.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502041/2000502041.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502041/._2000502041.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501066/2000501066.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501066/._2000501066.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502048/2000502048.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502048/._2000502048.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502077/2000502077.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502077/._2000502077.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501050/2000501050.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501050/._2000501050.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501057/2000501057.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501057/._2000501057.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502084/2000502084.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502084/._2000502084.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502070/2000502070.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502070/._2000502070.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501003/2000501003.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501003/._2000501003.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502023/2000502023.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502023/._2000502023.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501004/2000501004.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501004/._2000501004.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502015/2000502015.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502015/._2000502015.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501032/2000501032.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501032/._2000501032.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501035/2000501035.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501035/._2000501035.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502012/2000502012.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502012/._2000502012.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501028/2000501028.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501028/._2000501028.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502037/2000502037.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502037/._2000502037.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501010/2000501010.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501010/._2000501010.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501019/2000501019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501019/._2000501019.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502039/2000502039.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502039/._2000502039.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501021/2000501021.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501021/._2000501021.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502006/2000502006.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502006/._2000502006.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501075/2000501075.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501075/._2000501075.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502055/2000502055.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502055/._2000502055.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502063/2000502063.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502063/._2000502063.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501044/2000501044.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501044/._2000501044.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501043/2000501043.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501043/._2000501043.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502090/2000502090.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502090/._2000502090.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502007/2000502007.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502007/._2000502007.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501020/2000501020.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501020/._2000501020.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501018/2000501018.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501018/._2000501018.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501027/2000501027.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501027/._2000501027.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502009/2000502009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502009/._2000502009.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501011/2000501011.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501011/._2000501011.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502036/2000502036.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502036/._2000502036.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501016/2000501016.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501016/._2000501016.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502065/2000502065.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502065/._2000502065.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501042/2000501042.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501042/._2000501042.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501045/2000501045.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501045/._2000501045.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502062/2000502062.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502062/._2000502062.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502054/2000502054.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502054/._2000502054.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000502053/2000502053.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000502053/._2000502053.avi
#   inflating: /content/DAiSEE/DataSet/Train/200050/2000501074/2000501074.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/200050/2000501074/._2000501074.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141008/1100141008.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141008/._1100141008.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142010/1100142010.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142010/._1100142010.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142028/1100142028.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142028/._1100142028.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141030/1100141030.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141030/._1100141030.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142017/1100142017.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142017/._1100142017.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141039/1100141039.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141039/._1100141039.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141006/1100141006.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141006/._1100141006.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142021/1100142021.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142021/._1100142021.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142019/1100142019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142019/._1100142019.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141001/1100141001.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141001/._1100141001.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141055/1100141055.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141055/._1100141055.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141052/1100141052.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141052/._1100141052.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142043/1100142043.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142043/._1100142043.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142044/1100142044.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142044/._1100142044.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142018/1100142018.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142018/._1100142018.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142027/1100142027.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142027/._1100142027.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141007/1100141007.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141007/._1100141007.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142029/1100142029.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142029/._1100142029.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141031/1100141031.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141031/._1100141031.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141009/1100141009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141009/._1100141009.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141036/1100141036.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141036/._1100141036.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142011/1100142011.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142011/._1100142011.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142045/1100142045.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142045/._1100142045.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141053/1100141053.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141053/._1100141053.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141054/1100141054.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141054/._1100141054.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141049/1100141049.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141049/._1100141049.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142051/1100142051.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142051/._1100142051.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142056/1100142056.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142056/._1100142056.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142060/1100142060.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142060/._1100142060.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142058/1100142058.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142058/._1100142058.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141040/1100141040.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141040/._1100141040.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141014/1100141014.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141014/._1100141014.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142033/1100142033.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142033/._1100142033.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142034/1100142034.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142034/._1100142034.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141013/1100141013.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141013/._1100141013.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142002/1100142002.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142002/._1100142002.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142059/1100142059.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142059/._1100142059.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141046/1100141046.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141046/._1100141046.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142057/1100142057.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142057/._1100142057.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142050/1100142050.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142050/._1100142050.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142004/1100142004.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142004/._1100142004.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141023/1100141023.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141023/._1100141023.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142003/1100142003.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142003/._1100142003.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141012/1100141012.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141012/._1100141012.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142035/1100142035.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142035/._1100142035.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142032/1100142032.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142032/._1100142032.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141015/1100141015.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141015/._1100141015.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142049/1100142049.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142049/._1100142049.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141056/1100141056.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141056/._1100141056.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141033/1100141033.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141033/._1100141033.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142014/1100142014.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142014/._1100142014.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142013/1100142013.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142013/._1100142013.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141034/1100141034.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141034/._1100141034.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141002/1100141002.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141002/._1100141002.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141005/1100141005.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141005/._1100141005.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142022/1100142022.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142022/._1100142022.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142041/1100142041.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142041/._1100142041.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142046/1100142046.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142046/._1100142046.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141057/1100141057.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141057/._1100141057.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141050/1100141050.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141050/._1100141050.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142048/1100142048.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142048/._1100142048.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142023/1100142023.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142023/._1100142023.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141004/1100141004.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141004/._1100141004.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141003/1100141003.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141003/._1100141003.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142024/1100142024.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142024/._1100142024.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141035/1100141035.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141035/._1100141035.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142015/1100142015.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142015/._1100142015.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141032/1100141032.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141032/._1100141032.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141010/1100141010.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141010/._1100141010.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142008/1100142008.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142008/._1100142008.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141017/1100141017.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141017/._1100141017.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142030/1100142030.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142030/._1100142030.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141028/1100141028.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141028/._1100141028.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141021/1100141021.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141021/._1100141021.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141019/1100141019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141019/._1100141019.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142052/1100142052.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142052/._1100142052.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141044/1100141044.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141044/._1100141044.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141027/1100141027.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141027/._1100141027.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142007/1100142007.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142007/._1100142007.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141020/1100141020.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141020/._1100141020.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142038/1100142038.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142038/._1100142038.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142031/1100142031.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142031/._1100142031.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141016/1100141016.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141016/._1100141016.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141029/1100141029.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141029/._1100141029.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141011/1100141011.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141011/._1100141011.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142009/1100142009.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142009/._1100142009.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141045/1100141045.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141045/._1100141045.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100141042/1100141042.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100141042/._1100141042.avi
#   inflating: /content/DAiSEE/DataSet/Train/110014/1100142053/1100142053.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/110014/1100142053/._1100142053.avi
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510129/248510129.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510129/._248510129.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510116/248510116.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510116/._248510116.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510111/248510111.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510111/._248510111.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510118/248510118.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510118/._248510118.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510127/248510127.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510127/._248510127.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510120/248510120.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510120/._248510120.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510142/248510142.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510142/._248510142.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510119/248510119.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510119/._248510119.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510128/248510128.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510128/._248510128.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510117/248510117.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510117/._248510117.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510235/248510235.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510235/._248510235.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510232/248510232.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510232/._248510232.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510268/248510268.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510268/._248510268.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510250/248510250.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510250/._248510250.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510259/248510259.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510259/._248510259.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510233/248510233.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510233/._248510233.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510260/248510260.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510260/._248510260.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510267/248510267.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510267/._248510267.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510251/248510251.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510251/._248510251.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510256/248510256.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510256/._248510256.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510273/248510273.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510273/._248510273.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510245/248510245.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510245/._248510245.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510242/248510242.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510242/._248510242.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510216/248510216.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510216/._248510216.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510229/248510229.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510229/._248510229.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510211/248510211.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510211/._248510211.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510227/248510227.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510227/._248510227.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510220/248510220.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510220/._248510220.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510272/248510272.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510272/._248510272.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/24851014/24851014.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/24851014/._24851014.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510157/248510157.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510157/._248510157.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/24851013/24851013.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/24851013/._24851013.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510150/248510150.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510150/._248510150.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/24851022/24851022.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/24851022/._24851022.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510161/248510161.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510161/._248510161.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510160/248510160.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510160/._248510160.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/24851024/24851024.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/24851024/._24851024.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510167/248510167.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510167/._248510167.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510151/248510151.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510151/._248510151.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/24851015/24851015.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/24851015/._24851015.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510156/248510156.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510156/._248510156.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510170/248510170.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510170/._248510170.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510148/248510148.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510148/._248510148.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510112/248510112.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510112/._248510112.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510147/248510147.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510147/._248510147.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510125/248510125.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510125/._248510125.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510114/248510114.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510114/._248510114.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510253/248510253.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510253/._248510253.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510262/248510262.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510262/._248510262.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510265/248510265.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510265/._248510265.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510236/248510236.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510236/._248510236.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510264/248510264.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510264/._248510264.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510255/248510255.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510255/._248510255.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510230/248510230.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510230/._248510230.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510212/248510212.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510212/._248510212.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510215/248510215.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510215/._248510215.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510223/248510223.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510223/._248510223.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510248/248510248.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510248/._248510248.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510241/248510241.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510241/._248510241.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510246/248510246.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510246/._248510246.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510225/248510225.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510225/._248510225.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510214/248510214.mp4
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Train/248510/248510214/._248510214.mp4
#   inflating: /content/DAiSEE/DataSet/Train/248510/248510213/248510213.mp4
# ...
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630233/._5564630233.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630257/5564630257.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630257/._5564630257.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630261/5564630261.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630261/._5564630261.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630232/5564630232.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630232/._5564630232.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630235/5564630235.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630235/._5564630235.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630143/5564630143.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630143/._5564630143.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630126/5564630126.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630126/._5564630126.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630121/5564630121.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630121/._5564630121.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630128/5564630128.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630128/._5564630128.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630117/5564630117.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630117/._5564630117.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630110/5564630110.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630110/._5564630110.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630142/5564630142.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630142/._5564630142.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630145/5564630145.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630145/._5564630145.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630129/5564630129.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630129/._5564630129.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630127/5564630127.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630127/._5564630127.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630134/5564630134.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630134/._5564630134.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630133/5564630133.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630133/._5564630133.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630158/5564630158.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630158/._5564630158.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630167/5564630167.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630167/._5564630167.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463025/556463025.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463025/._556463025.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463022/556463022.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463022/._556463022.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630160/5564630160.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630160/._5564630160.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463014/556463014.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463014/._556463014.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630156/5564630156.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630156/._5564630156.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463013/556463013.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463013/._556463013.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630132/5564630132.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630132/._5564630132.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630135/5564630135.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630135/._5564630135.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463012/556463012.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463012/._556463012.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630150/5564630150.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630150/._5564630150.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630168/5564630168.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630168/._5564630168.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630157/5564630157.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630157/._5564630157.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630161/5564630161.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630161/._5564630161.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463024/556463024.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463024/._556463024.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630166/5564630166.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630166/._5564630166.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630226/5564630226.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630226/._5564630226.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630219/5564630219.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630219/._5564630219.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630221/5564630221.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630221/._5564630221.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630217/5564630217.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630217/._5564630217.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630228/5564630228.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630228/._5564630228.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630281/5564630281.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630281/._5564630281.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630275/5564630275.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630275/._5564630275.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630211/5564630211.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630211/._5564630211.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630216/5564630216.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630216/._5564630216.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630229/5564630229.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630229/._5564630229.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630218/5564630218.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630218/._5564630218.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630273/5564630273.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630273/._5564630273.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630230/5564630230.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630230/._5564630230.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630237/5564630237.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630237/._5564630237.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630264/5564630264.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630264/._5564630264.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630252/5564630252.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630252/._5564630252.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630236/5564630236.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630236/._5564630236.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630238/5564630238.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630238/._5564630238.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630254/5564630254.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630254/._5564630254.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630253/5564630253.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630253/._5564630253.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630265/5564630265.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630265/._5564630265.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630262/5564630262.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630262/._5564630262.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630122/5564630122.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630122/._5564630122.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630140/5564630140.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630140/._5564630140.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630147/5564630147.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630147/._5564630147.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630149/5564630149.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630149/._5564630149.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630115/5564630115.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630115/._5564630115.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630112/5564630112.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630112/._5564630112.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630123/5564630123.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630123/._5564630123.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630148/5564630148.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630148/._5564630148.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630141/5564630141.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630141/._5564630141.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630163/5564630163.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630163/._5564630163.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463019/556463019.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463019/._556463019.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463026/556463026.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463026/._556463026.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630152/5564630152.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630152/._5564630152.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463028/556463028.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463028/._556463028.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630139/5564630139.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630139/._5564630139.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630130/5564630130.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630130/._5564630130.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630137/5564630137.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630137/._5564630137.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463029/556463029.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463029/._556463029.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630154/5564630154.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630154/._5564630154.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463016/556463016.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463016/._556463016.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630153/5564630153.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630153/._5564630153.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463018/556463018.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463018/._556463018.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/556463027/556463027.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/556463027/._556463027.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630165/5564630165.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630165/._5564630165.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630162/5564630162.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630162/._5564630162.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630138/5564630138.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630138/._5564630138.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630240/5564630240.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630240/._5564630240.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630247/5564630247.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630247/._5564630247.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630249/5564630249.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630249/._5564630249.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630276/5564630276.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630276/._5564630276.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630222/5564630222.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630222/._5564630222.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630213/5564630213.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630213/._5564630213.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630241/5564630241.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630241/._5564630241.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630215/5564630215.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630215/._5564630215.avi
#   inflating: /content/DAiSEE/DataSet/Validation/556463/5564630212/5564630212.avi
#   inflating: /content/__MACOSX/DAiSEE/DataSet/Validation/556463/5564630212/._5564630212.avi

# %%
import urllib.request
import os

# URL to download the haarcascade_frontalface_default.xml file
HAARCASCADE_URL = 'https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml'
HAARCASCADE_FILENAME = 'haarcascade_frontalface_default.xml'

# Download the file if it doesn't exist
if not os.path.exists(HAARCASCADE_FILENAME):
    print(f"Downloading {HAARCASCADE_FILENAME}...")
    urllib.request.urlretrieve(HAARCASCADE_URL, HAARCASCADE_FILENAME)
    print(f"Successfully downloaded {HAARCASCADE_FILENAME}")
else:
    print(f"{HAARCASCADE_FILENAME} already exists.")
# Out:
# Downloading haarcascade_frontalface_default.xml...
# Successfully downloaded haarcascade_frontalface_default.xml

# %%
import cv2
import pandas as pd
import os
import shutil

# --- Configuration for Frame Extraction ---
# Define paths
base_video_dir = '/content/DAiSEE/DataSet'
output_frames_base_dir = '/content/DAiSEE_Faces_Binary' # Changed output to binary-specific directory
labels_dir = '/content/DAiSEE/Labels'

# Define the path for the face cascade XML file
# Using os.path.join(os.getcwd(), ...) for absolute path robustness
face_cascade_path = os.path.join(os.getcwd(), 'haarcascade_frontalface_default.xml')

# Load the face cascade classifier
face_cascade = cv2.CascadeClassifier(face_cascade_path)

# Check if cascade loaded successfully
if face_cascade.empty():
    print(f"Error: Failed to load face cascade from {os.path.abspath(face_cascade_path)}. ")
    print("Please ensure 'haarcascade_frontalface_default.xml' exists in the current directory and is valid.")
    raise RuntimeError("Face cascade classifier could not be loaded.")
else:
    print(f"Successfully loaded face cascade from: {os.path.abspath(face_cascade_path)}")

# Define target label column from your CSVs (this will be our newly created binary label)
TARGET_LABEL_COLUMN = 'BinaryEngagement' # New column name for binary label
FRAMES_PER_VIDEO = 5 # Number of frames to extract from each video

# Create base output directory for faces
os.makedirs(output_frames_base_dir, exist_ok=True)

# Helper function to determine binary engagement label
def get_binary_engagement_label(row):
    engagement = row.get('Engagement', 0)
    boredom = row.get('Boredom', 0)
    confusion = row.get('Confusion', 0)
    frustration = row.get('Frustration', 0)

    # Not Engaged conditions:
    # 1. Low engagement (0 or 1)
    # 2. OR presence of significant negative emotion (Boredom, Confusion, Frustration >= 2)
    if engagement <= 1 or boredom >= 2 or confusion >= 2 or frustration >= 2:
        return '0' # Not Engaged
    # Engaged conditions:
    # 1. High engagement (2 or 3) AND
    # 2. Absence of significant negative emotions (Boredom, Confusion, Frustration < 2)
    elif engagement >= 2 and boredom <= 1 and confusion <= 1 and frustration <= 1:
        return '1' # Engaged
    else:
        # Fallback for ambiguous cases, though the above rules should cover most
        return '0' # Default to Not Engaged for safety

def extract_and_organize_faces(label_df, video_base_path, output_base_path, set_name, label_column, frames_per_video, face_cascade):
    print(f"Processing {set_name} set...")
    total_videos = len(label_df)
    processed_videos = 0
    skipped_videos = 0
    no_face_detected_frames = 0

    # Clean up previous extractions for this set if they exist
    set_output_dir = os.path.join(output_base_path, set_name)
    if os.path.exists(set_output_dir):
        shutil.rmtree(set_output_dir)
    os.makedirs(set_output_dir)

    # Create binary class subdirectories (0 for Not Engaged, 1 for Engaged)
    os.makedirs(os.path.join(set_output_dir, '0'), exist_ok=True)
    os.makedirs(os.path.join(set_output_dir, '1'), exist_ok=True)

    for index, row in label_df.iterrows():
        # Get the full ClipID from the DataFrame, e.g., '2100601052.avi'
        full_clip_id_with_ext = str(row['ClipID'])
        label_value = str(row[label_column]) # Use the new binary label

        # Remove extension to get the folder name for the clip, e.g., '2100601052'
        clip_folder_name = os.path.splitext(full_clip_id_with_ext)[0]

        # Infer SubjectID from clip_folder_name (assuming first 6 digits for DAiSEE structure)
        if len(clip_folder_name) >= 6:
            subject_id = clip_folder_name[:6]
        else:
            print(f"Warning: ClipID '{full_clip_id_with_ext}' is too short to extract SubjectID. Skipping video.")
            skipped_videos += 1
            continue

        # Construct the actual video file path
        # Example: /content/DAiSEE/DataSet/Train/SubjectID/ClipFolder_Name/FullClipID_With_Ext
        current_video_path = os.path.join(base_video_dir, set_name, subject_id, clip_folder_name, full_clip_id_with_ext)

        if not os.path.exists(current_video_path):
            print(f"Video file not found for ClipID: {full_clip_id_with_ext} at {current_video_path}. Skipping.")
            skipped_videos += 1
            continue

        # Output directory for faces will be DAiSEE_Faces_Binary/{Train/Validation/Test}/{0 or 1}
        output_label_dir = os.path.join(set_output_dir, label_value)

        cap = cv2.VideoCapture(current_video_path)
        if not cap.isOpened():
            print(f"Error: Could not open video {current_video_path}. Skipping.")
            skipped_videos += 1
            cap.release()
            continue

        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        if frame_count == 0:
            print(f"Video {current_video_path} has 0 frames. Skipping.")
            skipped_videos += 1
            cap.release()
            continue

        # Extract frames evenly spaced throughout the video
        frame_indices = [int(i * frame_count / (frames_per_video + 1)) for i in range(1, frames_per_video + 1)]

        extracted_faces_count = 0
        for i, idx in enumerate(frame_indices):
            cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
            ret, frame = cap.read()
            if ret:
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                faces = face_cascade.detectMultiScale(gray, 1.3, 5)

                if len(faces) > 0:
                    # Sort faces by size (area) and pick the largest one
                    faces = sorted(faces, key=lambda x: x[2] * x[3], reverse=True)
                    (x, y, w, h) = faces[0]

                    # Expand the bounding box slightly
                    padding = int(0.2 * max(w, h)) # 20% padding
                    x_start = max(0, x - padding)
                    y_start = max(0, y - padding)
                    x_end = min(frame.shape[1], x + w + padding)
                    y_end = min(frame.shape[0], y + h + padding)

                    face_crop = frame[y_start:y_end, x_start:x_end]

                    # Use clip_folder_name for cleaner frame filenames
                    face_filename = os.path.join(output_label_dir, f"{clip_folder_name}_face_{idx:05d}.jpg")
                    cv2.imwrite(face_filename, face_crop)
                    extracted_faces_count += 1
                else:
                    no_face_detected_frames += 1
            else:
                pass # Suppress frequent warnings for brevity

        cap.release()
        processed_videos += 1
        if processed_videos % 100 == 0:
            print(f"Processed {processed_videos}/{total_videos} videos in {set_name} set.")

    print(f"Finished processing {set_name} set. Processed {processed_videos} videos, skipped {skipped_videos}, frames with no faces: {no_face_detected_frames}.")

# Load labels
print("Loading labels...")
train_labels_df = pd.read_csv(os.path.join(labels_dir, 'TrainLabels.csv'))
val_labels_df = pd.read_csv(os.path.join(labels_dir, 'ValidationLabels.csv'))
test_labels_df = pd.read_csv(os.path.join(labels_dir, 'TestLabels.csv')) # Load test labels

# --- DEBUG: Print columns to verify presence of 'Frustration' ---
print(f"TrainLabels.csv columns: {train_labels_df.columns.tolist()}")
print(f"ValidationLabels.csv columns: {val_labels_df.columns.tolist()}")
print(f"TestLabels.csv columns: {test_labels_df.columns.tolist()}")
# -----------------------------------------------------------------

# Apply the binary engagement logic to each dataframe
print("Applying new binary engagement classification logic...")
train_labels_df['BinaryEngagement'] = train_labels_df.apply(get_binary_engagement_label, axis=1)
val_labels_df['BinaryEngagement'] = val_labels_df.apply(get_binary_engagement_label, axis=1)
test_labels_df['BinaryEngagement'] = test_labels_df.apply(get_binary_engagement_label, axis=1)

# Perform face extraction using the newly calculated binary engagement label
extract_and_organize_faces(train_labels_df, base_video_dir, output_frames_base_dir, 'Train', TARGET_LABEL_COLUMN, FRAMES_PER_VIDEO, face_cascade)
extract_and_organize_faces(val_labels_df, base_video_dir, output_frames_base_dir, 'Validation', TARGET_LABEL_COLUMN, FRAMES_PER_VIDEO, face_cascade)
extract_and_organize_faces(test_labels_df, base_video_dir, output_frames_base_dir, 'Test', TARGET_LABEL_COLUMN, FRAMES_PER_VIDEO, face_cascade) # Extract test faces

print(f"All faces extracted and organized to: {output_frames_base_dir}")
# Out:
# Successfully loaded face cascade from: /content/haarcascade_frontalface_default.xml
# Loading labels...
# TrainLabels.csv columns: ['ClipID', 'Boredom', 'Engagement', 'Confusion', 'Frustration ']
# ValidationLabels.csv columns: ['ClipID', 'Boredom', 'Engagement', 'Confusion', 'Frustration ']
# TestLabels.csv columns: ['ClipID', 'Boredom', 'Engagement', 'Confusion', 'Frustration ']
# Applying new binary engagement classification logic...
# Processing Train set...
# Processed 100/5358 videos in Train set.
# Processed 200/5358 videos in Train set.
# Processed 300/5358 videos in Train set.
# Processed 400/5358 videos in Train set.
# Processed 500/5358 videos in Train set.
# Processed 600/5358 videos in Train set.
# Processed 700/5358 videos in Train set.
# Processed 800/5358 videos in Train set.
# Processed 900/5358 videos in Train set.
# Processed 1000/5358 videos in Train set.
# Processed 1100/5358 videos in Train set.
# Processed 1200/5358 videos in Train set.
# Processed 1300/5358 videos in Train set.
# Processed 1400/5358 videos in Train set.
# Processed 1500/5358 videos in Train set.
# Processed 1600/5358 videos in Train set.
# Processed 1700/5358 videos in Train set.
# Processed 1800/5358 videos in Train set.
# Processed 1900/5358 videos in Train set.
# Processed 2000/5358 videos in Train set.
# Processed 2100/5358 videos in Train set.
# Processed 2200/5358 videos in Train set.
# Processed 2300/5358 videos in Train set.
# Processed 2400/5358 videos in Train set.
# Processed 2500/5358 videos in Train set.
# Processed 2600/5358 videos in Train set.
# Processed 2700/5358 videos in Train set.
# Processed 2800/5358 videos in Train set.
# Processed 2900/5358 videos in Train set.
# Processed 3000/5358 videos in Train set.
# Processed 3100/5358 videos in Train set.
# Processed 3200/5358 videos in Train set.
# Processed 3300/5358 videos in Train set.
# Processed 3400/5358 videos in Train set.
# Processed 3500/5358 videos in Train set.
# Processed 3600/5358 videos in Train set.
# Processed 3700/5358 videos in Train set.
# Processed 3800/5358 videos in Train set.
# Processed 3900/5358 videos in Train set.
# Processed 4000/5358 videos in Train set.
# Processed 4100/5358 videos in Train set.
# Processed 4200/5358 videos in Train set.
# Processed 4300/5358 videos in Train set.
# Processed 4400/5358 videos in Train set.
# Processed 4500/5358 videos in Train set.
# Processed 4600/5358 videos in Train set.
# Processed 4700/5358 videos in Train set.
# Processed 4800/5358 videos in Train set.
# Processed 4900/5358 videos in Train set.
# Processed 5000/5358 videos in Train set.
# Processed 5100/5358 videos in Train set.
# Processed 5200/5358 videos in Train set.
# Processed 5300/5358 videos in Train set.
# Finished processing Train set. Processed 5358 videos, skipped 0, frames with no faces: 1944.
# Processing Validation set...
# Processed 100/1429 videos in Validation set.
# Processed 200/1429 videos in Validation set.
# Processed 300/1429 videos in Validation set.
# Processed 400/1429 videos in Validation set.
# Processed 500/1429 videos in Validation set.
# Processed 600/1429 videos in Validation set.
# Processed 700/1429 videos in Validation set.
# Processed 800/1429 videos in Validation set.
# Processed 900/1429 videos in Validation set.
# Processed 1000/1429 videos in Validation set.
# Processed 1100/1429 videos in Validation set.
# Processed 1200/1429 videos in Validation set.
# Processed 1300/1429 videos in Validation set.
# Processed 1400/1429 videos in Validation set.
# Finished processing Validation set. Processed 1429 videos, skipped 0, frames with no faces: 1093.
# Processing Test set...
# Processed 100/1784 videos in Test set.
# Processed 200/1784 videos in Test set.
# Processed 300/1784 videos in Test set.
# Processed 400/1784 videos in Test set.
# Processed 500/1784 videos in Test set.
# Processed 600/1784 videos in Test set.
# Processed 700/1784 videos in Test set.
# Processed 800/1784 videos in Test set.
# Processed 900/1784 videos in Test set.
# Processed 1000/1784 videos in Test set.
# Processed 1100/1784 videos in Test set.
# Processed 1200/1784 videos in Test set.
# Processed 1300/1784 videos in Test set.
# Processed 1400/1784 videos in Test set.
# Processed 1500/1784 videos in Test set.
# Processed 1600/1784 videos in Test set.
# Processed 1700/1784 videos in Test set.
# Finished processing Test set. Processed 1784 videos, skipped 0, frames with no faces: 987.
# All faces extracted and organized to: /content/DAiSEE_Faces_Binary

# %%
from torch.utils.data import Dataset
from PIL import Image # Import Image for loading images in the custom Dataset
import re # Import re for regex operations

class SingleFrameImageDataset(Dataset):
    def __init__(self, samples, transform=None):
        self.samples = samples # List of (image_path, label_idx) tuples
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        image = Image.open(path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# Helper function to get one frame per video ID from an ImageFolder dataset
def get_one_frame_per_video_samples(image_folder_dataset):
    filtered_samples = []
    video_ids_processed = set()

    for path, class_idx in image_folder_dataset.samples:
        # Extract video ID from filename. Example: 2100601052_face_00001.jpg -> 2100601052
        filename = os.path.basename(path)
        # Assuming filename format is {ClipID}_face_{frame_idx}.jpg
        match = re.match(r'(.+)_face_\d{5}\.jpg', filename)
        if match:
            video_id = match.group(1)
        else:
            # Fallback if filename format doesn't match, or use the full filename as ID
            video_id = filename.split('.')[0] # Fallback to filename without extension

        if video_id not in video_ids_processed:
            filtered_samples.append((path, class_idx))
            video_ids_processed.add(video_id)
    return filtered_samples

print("SingleFrameImageDataset class and get_one_frame_per_video_samples helper function defined.")
# Out:
# SingleFrameImageDataset class and get_one_frame_per_video_samples helper function defined.

# %%
import shutil
import os

# Define the source directory for the binary faces
source_binary_faces_dir = '/content/DAiSEE_Faces_Binary'
# Define the target directory in Google Drive
target_drive_dir = '/content/drive/MyDrive/DAiSEE_Processed_Faces_Binary'

print(f"Saving binary processed faces from {source_binary_faces_dir} to Google Drive at {target_drive_dir}...")

# Check if the target directory already exists in Drive and remove it to ensure a fresh copy
if os.path.exists(target_drive_dir):
    print(f"Removing existing directory in Drive: {target_drive_dir}")
    shutil.rmtree(target_drive_dir)

# Copy the entire directory to Google Drive
shutil.copytree(source_binary_faces_dir, target_drive_dir)

print("Binary processed faces successfully saved to Google Drive!")
print(f"You can find them at: {target_drive_dir}")
# Out:
# Saving binary processed faces from /content/DAiSEE_Faces_Binary to Google Drive at /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary...
# Removing existing directory in Drive: /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary
# Binary processed faces successfully saved to Google Drive!
# You can find them at: /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import os
import copy
import collections # Import collections for Counter

# --- Configuration ---
# You might need to adjust these paths based on your DAiSEE dataset structure
# The unzipping likely put the data in /content/DAiSEE/DataSet
data_dir = '/content/drive/MyDrive/DAiSEE_Processed_Faces_Binary' # CHANGED to point to restructured binary faces
# Assume classes are inferred from subdirectories, or specify if fixed
# num_classes = 4 # Example: for 4 engagement levels or 4 emotion categories

# Check if DAiSEE dataset directory exists
if not os.path.exists(data_dir):
    raise FileNotFoundError(f"DAiSEE dataset not found at {data_dir}. "
                            "Please ensure the dataset is unzipped correctly.")

# --- Device Setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Data Transformations ---
# Adapt these based on your `resnet_finetune.py`
data_transforms = {
    'Train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'Validation': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# --- Dataset and DataLoader ---
# Assuming your dataset structure is compatible with ImageFolder
# Original ImageFolder datasets
full_image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['Train', 'Validation']}

# Filter samples to get one frame per video
filtered_samples = {
    'Train': get_one_frame_per_video_samples(full_image_datasets['Train']),
    'Validation': get_one_frame_per_video_samples(full_image_datasets['Validation'])
}

# Create new custom datasets with filtered samples
image_datasets = {
    'Train': SingleFrameImageDataset(filtered_samples['Train'], data_transforms['Train']),
    'Validation': SingleFrameImageDataset(filtered_samples['Validation'], data_transforms['Validation'])
}

dataloaders = {x: DataLoader(image_datasets[x], batch_size=32,
                                            shuffle=True, num_workers=2)
               for x in ['Train', 'Validation']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['Train', 'Validation']}
# Explicitly set class names for clarity in binary classification
class_names = ['Not Engaged', 'Engaged']
num_classes = len(class_names)
print(f"Detected classes: {class_names}")
print(f"Number of classes: {num_classes}")

# --- Calculate Class Weights for Imbalanced Dataset ---
# Get all class labels from the training dataset
train_labels = [label for _, label in image_datasets['Train'].samples]
# Count occurrences of each class
class_counts = collections.Counter(train_labels)
# Convert counts to a list in order of class indices
class_counts_list = [class_counts[i] for i in range(num_classes)]

# Calculate inverse frequency weights: N_total / (N_classes * N_i)
# Or simply N_total / N_i for a more direct inverse frequency
total_samples = sum(class_counts_list)
# class_weights = [total_samples / (num_classes * count) for count in class_counts_list]
# A more common approach: inverse of the frequency
class_weights = [total_samples / count for count in class_counts_list]
class_weights = torch.tensor(class_weights, dtype=torch.float)
# Normalize weights if desired, but CrossEntropyLoss handles unnormalized weights fine
class_weights = class_weights / class_weights.sum()

print(f"Class counts: {class_counts_list}")
print(f"Calculated class weights: {class_weights.tolist()}")


# --- Model Setup ---
# Load a pre-trained ResNet model (e.g., ResNet-18)
model_ft = models.resnet18(weights='IMAGENET1K_V1') # Updated to remove deprecation warning

# Freeze all parameters in the network
# for param in model_ft.parameters():
#     param.requires_grad = False

# Modify the final fully connected layer to match the number of classes
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, num_classes)

# Move model to the selected device (GPU or CPU)
model_ft = model_ft.to(device)

# --- Loss Function and Optimizer ---
criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# You might want to add a learning rate scheduler here, e.g., StepLR
# from torch.optim import lr_scheduler
# exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# --- Training Function ---
def train_model(model, dataloaders, criterion, optimizer, num_epochs=20, scheduler=None): # Increased num_epochs
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Train', 'Validation']:
            if phase == 'Train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for batch_idx, (inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                if batch_idx % 100 == 0: # Print every 100 batches
                    print(f'  {phase} Batch {batch_idx}/{len(dataloaders[phase])} Loss: {running_loss / ((batch_idx + 1) * dataloaders[phase].batch_size):.4f} Acc: {running_corrects.double() / ((batch_idx + 1) * dataloaders[phase].batch_size):.4f}')

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model if it's the best validation accuracy
            if phase == 'Validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        # Step the scheduler at the end of each epoch if provided and in training phase
        if scheduler is not None:
            scheduler.step()

        print()

    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# --- Start Training ---
print("Starting model training...")
model_ft = train_model(model_ft, dataloaders, criterion, optimizer_ft, num_epochs=20) # Increased num_epochs

# --- Save the trained model ---
# You can choose a different name for your saved model
model_save_path = 'best_finetuned_resnet_model.pt'
torch.save(model_ft.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Using device: cuda
# Detected classes: ['Not Engaged', 'Engaged']
# Number of classes: 2
# Class counts: [1514, 3686]
# Calculated class weights: [0.7088461518287659, 0.29115384817123413]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 175MB/s]
# Starting model training...
# Epoch 0/19
# ----------
#   Train Batch 0/163 Loss: 0.8074 Acc: 0.3438
#   Train Batch 100/163 Loss: 0.7069 Acc: 0.5718
# Train Loss: 0.6921 Acc: 0.5921
#   Validation Batch 0/42 Loss: 0.6402 Acc: 0.5312
# Validation Loss: 0.6055 Acc: 0.5626
#
# Epoch 1/19
# ----------
#   Train Batch 0/163 Loss: 0.5168 Acc: 0.6875
#   Train Batch 100/163 Loss: 0.6630 Acc: 0.6278
# Train Loss: 0.6655 Acc: 0.6192
#   Validation Batch 0/42 Loss: 0.7905 Acc: 0.4688
# Validation Loss: 0.7294 Acc: 0.5633
#
# Epoch 2/19
# ----------
#   Train Batch 0/163 Loss: 0.7606 Acc: 0.4688
#   Train Batch 100/163 Loss: 0.6436 Acc: 0.6482
# Train Loss: 0.6391 Acc: 0.6481
#   Validation Batch 0/42 Loss: 0.7046 Acc: 0.6562
# Validation Loss: 0.7519 Acc: 0.5805
#
# Epoch 3/19
# ----------
#   Train Batch 0/163 Loss: 0.9950 Acc: 0.6250
#   Train Batch 100/163 Loss: 0.6302 Acc: 0.6683
# Train Loss: 0.6333 Acc: 0.6569
#   Validation Batch 0/42 Loss: 0.8518 Acc: 0.5000
# Validation Loss: 0.7584 Acc: 0.5857
#
# Epoch 4/19
# ----------
#   Train Batch 0/163 Loss: 0.5444 Acc: 0.7188
#   Train Batch 100/163 Loss: 0.6672 Acc: 0.6420
# Train Loss: 0.6538 Acc: 0.6471
#   Validation Batch 0/42 Loss: 0.6295 Acc: 0.5312
# Validation Loss: 0.6222 Acc: 0.5730
#
# Epoch 5/19
# ----------
#   Train Batch 0/163 Loss: 0.5571 Acc: 0.7188
#   Train Batch 100/163 Loss: 0.6482 Acc: 0.6507
# Train Loss: 0.6362 Acc: 0.6590
#   Validation Batch 0/42 Loss: 0.8717 Acc: 0.6250
# Validation Loss: 0.8385 Acc: 0.5917
#
# Epoch 6/19
# ----------
#   Train Batch 0/163 Loss: 0.5675 Acc: 0.8125
#   Train Batch 100/163 Loss: 0.6290 Acc: 0.6566
# Train Loss: 0.6218 Acc: 0.6658
#   Validation Batch 0/42 Loss: 0.5743 Acc: 0.5938
# Validation Loss: 0.6272 Acc: 0.5238
#
# Epoch 7/19
# ----------
#   Train Batch 0/163 Loss: 0.6577 Acc: 0.5938
#   Train Batch 100/163 Loss: 0.6359 Acc: 0.6485
# Train Loss: 0.6298 Acc: 0.6633
#   Validation Batch 0/42 Loss: 0.7710 Acc: 0.4688
# Validation Loss: 0.6490 Acc: 0.5723
#
# Epoch 8/19
# ----------
#   Train Batch 0/163 Loss: 0.6100 Acc: 0.6875
#   Train Batch 100/163 Loss: 0.6109 Acc: 0.6761
# Train Loss: 0.6126 Acc: 0.6715
#   Validation Batch 0/42 Loss: 0.6549 Acc: 0.5625
# Validation Loss: 0.6122 Acc: 0.5522
#
# Epoch 9/19
# ----------
#   Train Batch 0/163 Loss: 0.5562 Acc: 0.7188
#   Train Batch 100/163 Loss: 0.6002 Acc: 0.6887
# Train Loss: 0.6062 Acc: 0.6823
#   Validation Batch 0/42 Loss: 0.7359 Acc: 0.4688
# Validation Loss: 0.6313 Acc: 0.6073
#
# Epoch 10/19
# ----------
#   Train Batch 0/163 Loss: 0.5539 Acc: 0.7812
#   Train Batch 100/163 Loss: 0.6173 Acc: 0.6699
# Train Loss: 0.6248 Acc: 0.6729
#   Validation Batch 0/42 Loss: 0.7386 Acc: 0.3438
# Validation Loss: 0.6425 Acc: 0.5365
#
# Epoch 11/19
# ----------
#   Train Batch 0/163 Loss: 0.6503 Acc: 0.7188
#   Train Batch 100/163 Loss: 0.5963 Acc: 0.6894
# Train Loss: 0.6033 Acc: 0.6813
#   Validation Batch 0/42 Loss: 0.5166 Acc: 0.5625
# Validation Loss: 0.6464 Acc: 0.4911
#
# Epoch 12/19
# ----------
#   Train Batch 0/163 Loss: 0.5469 Acc: 0.6562
#   Train Batch 100/163 Loss: 0.6042 Acc: 0.6912
# Train Loss: 0.6154 Acc: 0.6771
#   Validation Batch 0/42 Loss: 0.6373 Acc: 0.4688
# Validation Loss: 0.5973 Acc: 0.5492
#
# Epoch 13/19
# ----------
#   Train Batch 0/163 Loss: 0.6607 Acc: 0.6250
#   Train Batch 100/163 Loss: 0.6011 Acc: 0.6813
# Train Loss: 0.5996 Acc: 0.6871
#   Validation Batch 0/42 Loss: 0.7974 Acc: 0.5938
# Validation Loss: 0.8132 Acc: 0.5902
#
# Epoch 14/19
# ----------
#   Train Batch 0/163 Loss: 0.5752 Acc: 0.8125
#   Train Batch 100/163 Loss: 0.5980 Acc: 0.6903
# Train Loss: 0.5995 Acc: 0.6819
#   Validation Batch 0/42 Loss: 0.4659 Acc: 0.7812
# Validation Loss: 0.6355 Acc: 0.6103
#
# Epoch 15/19
# ----------
#   Train Batch 0/163 Loss: 0.4997 Acc: 0.7500
#   Train Batch 100/163 Loss: 0.5837 Acc: 0.6968
# Train Loss: 0.5961 Acc: 0.6869
#   Validation Batch 0/42 Loss: 0.5158 Acc: 0.5625
# Validation Loss: 0.5999 Acc: 0.5194
#
# Epoch 16/19
# ----------
#   Train Batch 0/163 Loss: 0.6338 Acc: 0.5625
#   Train Batch 100/163 Loss: 0.5904 Acc: 0.6860
# Train Loss: 0.5838 Acc: 0.6885
#   Validation Batch 0/42 Loss: 0.7071 Acc: 0.5000
# Validation Loss: 0.7054 Acc: 0.6058
#
# Epoch 17/19
# ----------
#   Train Batch 0/163 Loss: 0.5608 Acc: 0.7188
#   Train Batch 100/163 Loss: 0.6196 Acc: 0.6593
# Train Loss: 0.6064 Acc: 0.6748
#   Validation Batch 0/42 Loss: 0.6568 Acc: 0.4688
# Validation Loss: 0.6139 Acc: 0.5209
#
# Epoch 18/19
# ----------
#   Train Batch 0/163 Loss: 0.6773 Acc: 0.6562
#   Train Batch 100/163 Loss: 0.5773 Acc: 0.6940
# Train Loss: 0.5886 Acc: 0.6838
#   Validation Batch 0/42 Loss: 0.5706 Acc: 0.6562
# Validation Loss: 0.6233 Acc: 0.5343
#
# Epoch 19/19
# ----------
#   Train Batch 0/163 Loss: 0.3953 Acc: 0.8125
#   Train Batch 100/163 Loss: 0.5909 Acc: 0.6897
# Train Loss: 0.5856 Acc: 0.6894
#   Validation Batch 0/42 Loss: 0.5553 Acc: 0.5938
# Validation Loss: 0.6562 Acc: 0.5112
#
# Best val Acc: 0.610283
# Model saved to best_finetuned_resnet_model.pt

# %%
import torch
import torch.nn as nn
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import os

# --- Configuration (reuse from training cell) ---
data_dir = '/content/drive/MyDrive/DAiSEE_Processed_Faces_Binary' # CHANGED to point to restructured binary faces
labels_dir = '/content/DAiSEE/Labels' # For reference, though not directly used here for loading images
model_save_path = 'best_finetuned_resnet_model.pt'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Data Transformations for Test Set ---
# Use the same transformations as validation set
test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# --- Load Test Dataset and DataLoader ---
# Original ImageFolder dataset
full_test_dataset = datasets.ImageFolder(os.path.join(data_dir, 'Test'), test_transforms)

# Filter samples to get one frame per video
filtered_test_samples = get_one_frame_per_video_samples(full_test_dataset)

# Create new custom test dataset with filtered samples
test_dataset = SingleFrameImageDataset(filtered_test_samples, test_transforms)

test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
test_dataset_size = len(test_dataset)
# Explicitly set test class names for clarity in binary classification
test_class_names = ['Not Engaged', 'Engaged']
num_classes = len(test_class_names)

print(f"Detected test classes: {test_class_names}")
print(f"Number of test samples: {test_dataset_size}")

# --- Model Setup ---
# Load the pre-trained ResNet model architecture
model_eval = models.resnet18(weights='IMAGENET1K_V1') # Updated to remove deprecation warning
num_ftrs = model_eval.fc.in_features
model_eval.fc = nn.Linear(num_ftrs, num_classes)

# Load the best weights from the saved model
if os.path.exists(model_save_path):
    model_eval.load_state_dict(torch.load(model_save_path, map_location=device))
    print(f"Successfully loaded model weights from {model_save_path}")
else:
    raise FileNotFoundError(f"Saved model not found at {model_save_path}. "
                            "Please ensure the training cell was run and model saved.")

model_eval = model_eval.to(device);
model_eval.eval() # Set model to evaluation mode

# --- Evaluation Function ---
def evaluate_model(model, dataloader, criterion):
    running_loss = 0.0
    running_corrects = 0

    # Iterate over data.
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        with torch.no_grad(): # No need to track gradients for evaluation
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    total_loss = running_loss / len(dataloader.dataset)
    total_acc = running_corrects.double() / len(dataloader.dataset)

    print(f'Test Loss: {total_loss:.4f} Acc: {total_acc:.4f}')
    return total_loss, total_acc

# --- Start Evaluation ---
print("Starting model evaluation on test set...")
criterion = nn.CrossEntropyLoss() # Use the same criterion as during training
test_loss, test_accuracy = evaluate_model(model_eval, test_dataloader, criterion)
print(f"Final Test Accuracy: {test_accuracy:.4f}")
# Out:
# Detected test classes: ['Not Engaged', 'Engaged']
# Number of test samples: 1713
# Successfully loaded model weights from best_finetuned_resnet_model.pt
# Starting model evaluation on test set...
# Test Loss: 0.6911 Acc: 0.5890
# Final Test Accuracy: 0.5890

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

print("Generating detailed performance metrics...")

all_preds = []
all_labels = []

model_eval.eval() # Ensure model is in evaluation mode
with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_eval(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Convert to numpy arrays
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Define binary class names for reporting
binary_class_names = ['Not Engaged', 'Engaged']

# 1. Classification Report
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=binary_class_names))

# 2. Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=binary_class_names, yticklabels=binary_class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Generating detailed performance metrics...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Not Engaged       0.36      0.52      0.42       502
#      Engaged       0.76      0.62      0.68      1211
#
#     accuracy                           0.59      1713
#    macro avg       0.56      0.57      0.55      1713
# weighted avg       0.64      0.59      0.61      1713

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt
import torch.nn.functional as F

print("Calculating Precision-Recall Curve for ResNet-18...")

# Re-load the model to ensure we have the correct state
model_resnet = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs_resnet = model_resnet.fc.in_features
model_resnet.fc = nn.Linear(num_ftrs_resnet, num_classes)
model_resnet.load_state_dict(torch.load(model_save_path, map_location=device))
model_resnet = model_resnet.to(device)
model_resnet.eval() # Set model to evaluation mode

all_probs_resnet = []
all_labels_pr_resnet = []

with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_resnet(inputs)
        # Get probabilities for the positive class (Engaged, which is index 1)
        probs = F.softmax(outputs, dim=1)[:, 1]
        all_probs_resnet.extend(probs.cpu().numpy())
        all_labels_pr_resnet.extend(labels.cpu().numpy())

# Calculate precision and recall
precision_resnet, recall_resnet, _ = precision_recall_curve(all_labels_pr_resnet, all_probs_resnet)
auc_score_resnet = auc(recall_resnet, precision_resnet)

# Plot the Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall_resnet, precision_resnet, label=f'ResNet-18 (AUC = {auc_score_resnet:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for ResNet-18')
plt.legend()
plt.grid(True)
plt.show()

print(f"ResNet-18 Precision-Recall AUC: {auc_score_resnet:.2f}")
# Out:
# Calculating Precision-Recall Curve for ResNet-18...
# ResNet-18 Precision-Recall AUC: 0.77

# %%
import os
import shutil
import matplotlib.pyplot as plt
import seaborn as sns
import torch.nn.functional as F
from sklearn.metrics import precision_recall_curve, auc, confusion_matrix, classification_report

# Define the target directory in Google Drive for results
drive_results_dir = os.path.join('/content/drive/MyDrive/DAiSEE_Processed_Faces_Binary', 'results')
os.makedirs(drive_results_dir, exist_ok=True)

# 1. Save the trained model to Google Drive
saved_model_filename = 'best_finetuned_resnet_model.pt'
source_model_path = saved_model_filename
target_model_path = os.path.join(drive_results_dir, saved_model_filename)

if os.path.exists(source_model_path):
    shutil.copy(source_model_path, target_model_path)
    print(f"Trained model '{saved_model_filename}' successfully copied to Drive: {target_model_path}")
else:
    print(f"Warning: Trained model '{saved_model_filename}' not found at {source_model_path}. Skipping save to Drive.")
# Out:
# Trained model 'best_finetuned_resnet_model.pt' successfully copied to Drive: /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary/results/best_finetuned_resnet_model.pt

# %%
# 2. Save the Confusion Matrix plot to Google Drive
# Re-generate the confusion matrix plot to save it
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=binary_class_names, yticklabels=binary_class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

confusion_matrix_save_path = os.path.join(drive_results_dir, 'confusion_matrix.png')
plt.savefig(confusion_matrix_save_path)
plt.close() # Close the plot to prevent it from being displayed twice
print(f"Confusion Matrix plot saved to Drive: {confusion_matrix_save_path}")
# Out:
# Confusion Matrix plot saved to Drive: /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary/results/confusion_matrix.png

# %%
# 3. Save the Precision-Recall Curve plot to Google Drive
# Re-generate the PR curve plot to save it
plt.figure(figsize=(8, 6))
plt.plot(recall_resnet, precision_resnet, label=f'ResNet-18 (AUC = {auc_score_resnet:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for ResNet-18')
plt.legend()
plt.grid(True)

pr_curve_save_path = os.path.join(drive_results_dir, 'precision_recall_curve.png')
plt.savefig(pr_curve_save_path)
plt.close() # Close the plot
print(f"Precision-Recall Curve plot saved to Drive: {pr_curve_save_path}")
# Out:
# Precision-Recall Curve plot saved to Drive: /content/drive/MyDrive/DAiSEE_Processed_Faces_Binary/results/precision_recall_curve.png

# %% [markdown]
# All significant generated outputs (trained model weights, confusion matrix plot, and precision-recall curve plot) have been saved to your Google Drive in the `DAiSEE_Processed_Faces_Binary/results` directory. You can find them at: `/content/drive/MyDrive/DAiSEE_Processed_Faces_Binary/results`
